# %% [markdown]
# <a href="https://colab.research.google.com/github/DaiyanNDahy/FlyRankInternML/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DaiyanNDahy/FlyRankInternML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
print("ML Task Type: Ranking confirmed.")
# Out:
# ML Task Type: Ranking confirmed.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
print("Target/Proxy: Relevance score or engagement probability confirmed.")
# Out:
# Target/Proxy: Relevance score or engagement probability confirmed.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
print("Success Metric: Normalized Discounted Cumulative Gain (NDCG) @ k confirmed.")
# Out:
# Success Metric: Normalized Discounted Cumulative Gain (NDCG) @ k confirmed.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
from datasets import load_dataset
import numpy as np

# Load the dataset
ds = load_dataset("FlyRank/internship-starter")

# Convert the 'train' split to a pandas DataFrame
df = ds['train'].to_pandas()

# Display the first 5 rows to show the unit of analysis
print("Unit of analysis (first 5 rows):")
display(df.head())

# Adding a placeholder for a 'relevance_score' column.
# In a real system, this would be calculated from user behavior (e.g., clicks, time spent).
# For this exercise, we'll create a synthetic one just to show its presence.
df['relevance_score'] = np.random.rand(len(df)) # Placeholder: random scores

print("\nDataFrame with a sketched 'relevance_score' column:")
display(df.head())
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# content_refresh_anonymized.csv:   0%|          | 0.00/8.23M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/30000 [00:00<?, ? examples/s]
# Unit of analysis (first 5 rows):
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
print("Why ML beats fixed rule: Complexity, personalization, and dynamic nature of data confirmed.")
# Out:
# Why ML beats fixed rule: Complexity, personalization, and dynamic nature of data confirmed.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
